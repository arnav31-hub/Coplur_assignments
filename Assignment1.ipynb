# %%
#1) Practicing print statement:

#with multiple object:
print("Hello","python",1,2.15)

#with seperator:
print("Math","English","Science",sep=",")

#with "ends":
print("How are",end=" ")
print("you")
# Out:
# Hello python 1 2.15
# Math,English,Science
# How are you

# %%
#1) Practicing print statement:

#with multiple object:
print("Hello","python",1,2.15)

#with seperator:
print("Math","English","Science",sep=",")

#with "ends":
print("How are",end=" ")
print("you")
# Out:
# Hello python 1 2.15
# Math,English,Science
# How are you

# %%
#2)Using input ask user to enter his/her name and output user name with a greeting message:
name = input("Enter your name")
print("Welcome," + name + "!It is great to see you today.")
# Out:
# Welcome,Arnav Mathur!It is great to see you today.
